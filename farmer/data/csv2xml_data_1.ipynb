# %%
import pandas as pd
import numpy as np

# %%
csv=pd.read_csv("temp.csv",delimiter='\t')

# %%
csv
# Out:
#      code    id                          name                name_np  parent
# 0    2481  3075  Basbariya Rural Municipality     बसबरिया गाउँपालिका    2026
# 1    2482  3076     Kodena Rural Municipality      कोडैना गाउँपालिका    2026
# 2    2483  3077      Parsa Rural Municipality       पर्सा गाउँपालिका    2026
# 3    2374  2374   Manara Shisawa Municipaltiy   मनरा शिसवा नगरपालिका    2025
# 4    2356  2356        Bardibas  Municipaltiy     बर्दिबास नगरपालिका    2025
# ..    ...   ...                           ...                    ...     ...
# 826  3303  3085  Bisrampur Rural Municipality  विश्रामपुर गाउँपालिका    2028
# 827  2914  2914       Bahudramai  Muncipality     बहुदरमाई नगरपालिका    2029
# 828  3304  3080      thori Rural Municipality        ठोरी गाउँपालिका    2029
# 829  2663  2663    Myagang Rural Municipality      म्यागङ गाउँपालिका    2036
# 830  2916  2916   Kalikamai Rural Mumcipality   कालिकामाई गाउँपालीका    2029
#
# [831 rows x 5 columns]

# %%
province_id_dict={'Sudur Paschim Province': 'location_province_1', 'Gandaki Province': 'location_province_2', 'Bagmati Province': 'location_province_3', 'Karnali Province': 'location_province_4', 'Lumbini Province': 'location_province_5', 'Madesh Province': 'location_province_6', 'Koshi Province': 'location_province_7'}

# %%
province_code_id = {'2007': 'location_province_1', '2004': 'location_province_2', '2003': 'location_province_3', '2006': 'location_province_4', '2005': 'location_province_5', '2002': 'location_province_6', '2001': 'location_province_7'}

# %%
district_dictionary={'Arghakhanchi': 'location_district_1', 'Humla': 'location_district_2', 'Gulmi': 'location_district_3', 'Kalikot': 'location_district_4', 'Jajarkot': 'location_district_5', 'Dailekh': 'location_district_6', 'Taplejung': 'location_district_7', 'Panchthar': 'location_district_8', 'Ilam': 'location_district_9', 'Sankhuwasabha': 'location_district_10', 'Terhathum': 'location_district_11', 'Dhankuta': 'location_district_12', 'Bhojpur': 'location_district_13', 'Khotang': 'location_district_14', 'Solukhumbu': 'location_district_15', 'Okhaldhunga': 'location_district_16', 'Udayapur': 'location_district_17', 'Jhapa': 'location_district_18', 'Morang': 'location_district_19', 'Sunsari': 'location_district_20', 'Saptari': 'location_district_21', 'Siraha': 'location_district_22', 'Dhanusha': 'location_district_23', 'Mahottari': 'location_district_24', 'Sarlahi': 'location_district_25', 'Rautahat': 'location_district_26', 'Bara': 'location_district_27', 'Parsa': 'location_district_28', 'Dolakha': 'location_district_29', 'Ramechhap': 'location_district_30', 'Sindhuli': 'location_district_31', 'Kavrepalanchok': 'location_district_32', 'Sindhupalchok': 'location_district_33', 'Rasuwa': 'location_district_34', 'Nuwakot': 'location_district_35', 'Dhading': 'location_district_36', 'Chitwan': 'location_district_37', 'Makawanpur': 'location_district_38', 'Bhaktapur': 'location_district_39', 'Lalitpur': 'location_district_40', 'Gorkha': 'location_district_41', 'Lamjung': 'location_district_42', 'Tanahun': 'location_district_43', 'Kaski': 'location_district_44', 'Manang': 'location_district_45', 'Mustang': 'location_district_46', 'Parbat': 'location_district_47', 'Syangja': 'location_district_48', 'Myagdi': 'location_district_49', 'Baglung': 'location_district_50', 'Nawalparasi (Eastern Part from Bardaghat Susta)': 'location_district_51', 'Nawalparasi (Western Part from Bardaghat Susta)': 'location_district_52', 'Rupandehi': 'location_district_53', 'Kapilvastu': 'location_district_54', 'Palpa': 'location_district_55', 'Rukum (Eastern Part)': 'location_district_56', 'Rolpa': 'location_district_57', 'Pyuthan': 'location_district_58', 'Dang': 'location_district_59', 'Banke': 'location_district_60', 'Bardiya': 'location_district_61', 'Rukum (Western Part)': 'location_district_62', 'Salyan': 'location_district_63', 'Dolpa': 'location_district_64', 'Jumla': 'location_district_65', 'Mugu': 'location_district_66', 'Surkhet': 'location_district_67', 'Bajura': 'location_district_68', 'Bajhang': 'location_district_69', 'Doti': 'location_district_70', 'Achham': 'location_district_71', 'Darchula': 'location_district_72', 'Baitadi': 'location_district_73', 'Dadeldhura': 'location_district_74', 'Kanchanpur': 'location_district_75', 'Kailali': 'location_district_76', 'Kathmandu': 'location_district_77'}

# %%
district_code_id = {'2058': 'location_district_1', '2071': 'location_district_2', '2059': 'location_district_3', '2072': 'location_district_4', '2073': 'location_district_5', '2074': 'location_district_6', '2008': 'location_district_7', '2009': 'location_district_8', '2010': 'location_district_9', '2011': 'location_district_10', '2012': 'location_district_11', '2013': 'location_district_12', '2014': 'location_district_13', '2015': 'location_district_14', '2016': 'location_district_15', '2017': 'location_district_16', '2018': 'location_district_17', '2019': 'location_district_18', '2020': 'location_district_19', '2021': 'location_district_20', '2022': 'location_district_21', '2023': 'location_district_22', '2024': 'location_district_23', '2025': 'location_district_24', '2026': 'location_district_25', '2027': 'location_district_26', '2028': 'location_district_27', '2029': 'location_district_28', '2030': 'location_district_29', '2031': 'location_district_30', '2032': 'location_district_31', '2033': 'location_district_32', '2034': 'location_district_33', '2035': 'location_district_34', '2036': 'location_district_35', '2037': 'location_district_36', '2038': 'location_district_37', '2039': 'location_district_38', '2040': 'location_district_39', '2041': 'location_district_40', '2043': 'location_district_41', '2044': 'location_district_42', '2045': 'location_district_43', '2046': 'location_district_44', '2047': 'location_district_45', '2048': 'location_district_46', '2049': 'location_district_47', '2050': 'location_district_48', '2051': 'location_district_49', '2052': 'location_district_50', '2053': 'location_district_51', '2054': 'location_district_52', '2055': 'location_district_53', '2056': 'location_district_54', '2057': 'location_district_55', '2060': 'location_district_56', '2061': 'location_district_57', '2062': 'location_district_58', '2063': 'location_district_59', '2064': 'location_district_60', '2065': 'location_district_61', '2066': 'location_district_62', '2067': 'location_district_63', '2068': 'location_district_64', '2069': 'location_district_65', '2070': 'location_district_66', '2075': 'location_district_67', '2076': 'location_district_68', '2077': 'location_district_69', '2078': 'location_district_70', '2079': 'location_district_71', '2080': 'location_district_72', '2081': 'location_district_73', '2082': 'location_district_74', '2083': 'location_district_75', '2084': 'location_district_76', '2042': 'location_district_77'}

# %%
palika_dictionary ={'Basbariya Rural Municipality': 'location_palika_1', 'Kodena Rural Municipality': 'location_palika_2', 'Parsa Rural Municipality': 'location_palika_3', 'Manara Shisawa Municipaltiy': 'location_palika_4', 'Bardibas  Municipaltiy': 'location_palika_5', 'Matihani Municipaltiy': 'location_palika_6', 'Maee Municipality': 'location_palika_7', 'Mechinagar Municipality': 'location_palika_8', 'Kankai municipality': 'location_palika_9', 'Inaruwa Muncipality': 'location_palika_10', 'Ramdhuni Municipality': 'location_palika_11', 'Barabise Municipality': 'location_palika_12', 'Melamchi Municipality': 'location_palika_13', 'Jaimini Municipality': 'location_palika_14', 'Tulshipur SMC': 'location_palika_15', 'Ghorahi SMC': 'location_palika_16', 'Nepalgunj SMC': 'location_palika_17', 'Dhangadi SMC': 'location_palika_18', 'Kathmandu Metropolian': 'location_palika_19', 'Fungling Municipality': 'location_palika_20', 'Ilam  Municipaltiy': 'location_palika_21', 'Gauradaha Municipality': 'location_palika_22', 'Belbari Municipality': 'location_palika_23', 'Letang Municipality': 'location_palika_24', 'Rangali Muncipality': 'location_palika_25', 'Urlabari Municipaltiy': 'location_palika_26', 'Sundarharicha Muncipality': 'location_palika_27', 'Lamhi Municipality': 'location_palika_28', 'Pakhirbas  Municipaltiy': 'location_palika_29', 'Kohalpur Municipality': 'location_palika_30', 'Jiri Municipality': 'location_palika_31', 'Suryodaya Municipaltiy': 'location_palika_32', 'Shidhicharana Municipality': 'location_palika_33', 'Shivasataxi Municipality': 'location_palika_34', 'Birtamoda Municipality': 'location_palika_35', 'Pathari Sanischare Municipality': 'location_palika_36', 'Sunbarsi Municipality': 'location_palika_37', 'Dharan Sub-Metropolitan City': 'location_palika_38', 'Janakpurdham Sub-Metropolitan City': 'location_palika_39', 'Butwal Sub-Metropolitan City': 'location_palika_40', 'Katari Municipality': 'location_palika_41', 'Chaudadhigadi Municipality': 'location_palika_42', 'Triyuga Municipality': 'location_palika_43', 'Belaka Municipality': 'location_palika_44', 'Guleriya Municipality': 'location_palika_45', 'Barbardiya Municipality': 'location_palika_46', 'MADHUBAN MUNICIPALITY': 'location_palika_47', 'RAJPUR MUNICIPALITY': 'location_palika_48', 'Thakurbaba Municipality': 'location_palika_49', 'BANSGADHI MUNICIPALITY': 'location_palika_50', 'Pyuthan Municipality': 'location_palika_51', 'Sorgadhawori Municipality': 'location_palika_52', 'Sukhipur Municipaltiy': 'location_palika_53', 'Devdaha Municipality': 'location_palika_54', 'Lumbini Saskrit Municipality': 'location_palika_55', 'Sainamaina Municipality': 'location_palika_56', 'ROLPA MUNICIPALITY': 'location_palika_57', 'Siddharthanagar Municipality': 'location_palika_58', 'Tilottama Municipality': 'location_palika_59', 'MUSHIKOT MUNICIPALITY': 'location_palika_60', 'RESUNGA MUNICIPALITY': 'location_palika_61', 'Tansen Municipality': 'location_palika_62', 'Bardaghat Municipality': 'location_palika_63', 'Ramgram Municipality': 'location_palika_64', 'Sunabol Municipality': 'location_palika_65', 'Buddhabhumi Municipality': 'location_palika_66', 'Shivaraj Municip
_438', 'Tirpurasundari Rural Municipality': 'location_palika_439', 'Khanikhola Rural Municipality': 'location_palika_440', 'Chaurideaurali Rural Municipality': 'location_palika_441', 'Bethanchowok Rural Municipality': 'location_palika_442', 'Bhumlu Rural Municipality': 'location_palika_443', 'Putha utarganga Rural Municipality': 'location_palika_444', 'Bhume  Rural Municipality': 'location_palika_445', 'Konjyoshoma Rural Municipality': 'location_palika_446', 'Bagmati Rural Municipality': 'location_palika_522', 'Mahanala Rural Municipality': 'location_palika_448', 'Gaumul Rural Municipality': 'location_palika_449', 'HIMALI RURAL MUNICIPALITY': 'location_palika_450', 'TALKOT RURAL MUNICIPALITY': 'location_palika_451', 'MASTA RURAL MUNICIPALITY': 'location_palika_452', 'KHAPTADCHHATRA Rural Municipaltiy': 'location_palika_453', 'Thalara Rural Municipality': 'location_palika_454', 'Bitthadachir Rural Municipality': 'location_palika_455', 'Surma Rural Municipality': 'location_palika_456', 'Chabispathivera Rural Municipality': 'location_palika_457', 'Durgathali Rural Municipality': 'location_palika_458', 'Kedarsyun Rural Municipality': 'location_palika_459', 'Churpati Rural Municipality': 'location_palika_460', 'Mellekha Rural Municipality': 'location_palika_461', 'Batrigadi Jaygadi Rural Municipality': 'location_palika_462', 'Bulintar Rural Municipaltiy': 'location_palika_463', 'Hupsekot Rural Municipality': 'location_palika_464', 'Sarabal Rural Municipaltiy': 'location_palika_465', 'Sisne  Rural Municipality': 'location_palika_466', 'Mahavarat Rural Municipality': 'location_palika_468', 'Roshi Rural Municipality': 'location_palika_469', 'Dupcheshowar Rural Municipality': 'location_palika_470', 'Baphikot  Rural Municipality': 'location_palika_471', 'Sanibheri  Rural Municipality': 'location_palika_472', 'Aautirgaya Rural Municipality': 'location_palika_473', 'Chingad  Rural Municipality': 'location_palika_474', 'Jagannath RURAL MUNICIPALITY': 'location_palika_475', 'SWAMIKARTIK khapar RURAL MUNICIPALITY': 'location_palika_476', 'Khaptad Chhededaha MUNICIPALITY': 'location_palika_477', 'Temal Rural Municipality': 'location_palika_478', 'Kakani Rural Municipality': 'location_palika_479', 'Kalika Rural Municipality': 'location_palika_480', 'Goshahikundha Rural Municipality': 'location_palika_481', 'Naukundha Rural Municipality': 'location_palika_482', 'Aamachhodingmo Rular Municipality': 'location_palika_483', 'Tadi Rural Municipality': 'location_palika_484', 'Tarakeshowar Rural Municipality': 'location_palika_485', 'Partappur Rural Municipality': 'location_palika_486', 'Ramaroshan Rural Municipality': 'location_palika_487', 'Dhakari Rural Municipality': 'location_palika_488', 'Turmakhad Rural Municipality': 'location_palika_489', 'Purbichuki Rural Municipality': 'location_palika_490', 'Badikedar Rural Municipality': 'location_palika_491', 'Jorayal Rural Municipality': 'location_palika_492', 'Sayal Rural Municipality': 'location_palika_493', 'Aadarsha Rural Municipality': 'location_palika_494', 'K.I.C Rural Municipality': 'location_palika_495', 'Gauriganga Municipality': 'location_palika_496', 'Bardagoriya  Rural Municipality': 'location_palika_498', 'Mohanyal  Rural Municipality': 
yapur  Muncipality': 'location_palika_562', 'Ishnath  Muncipality': 'location_palika_563', 'Paroha  Muncipality': 'location_palika_564', 'Rajapur  Muncipality': 'location_palika_565', 'Kabholasothar  Rural Municipality': 'location_palika_566', 'dudhapokhari Rural Municipality': 'location_palika_567', 'Dodri Rural Municipality': 'location_palika_568', 'Marsand Rural Municipality': 'location_palika_569', 'Baragadhi Rural Muncipality': 'location_palika_570', 'Simta  Rural Municipality': 'location_palika_571', 'Birgunj MetropolitanCity': 'location_palika_572', 'Bhagwatimae  Rural Municipality': 'location_palika_573', 'Guras  Rural Municipality': 'location_palika_574', 'Dungedhar  Rural Municipality': 'location_palika_575', 'Naumule  Rural Municipality': 'location_palika_576', 'Mahabu  Rural Municipality': 'location_palika_577', 'Bhirabi  Rural Municipality': 'location_palika_578', 'Thatikadha  Rural Municipality': 'location_palika_579', 'Junicade  Rural Municipality': 'location_palika_580', 'Barekot  Rural Municipality': 'location_palika_581', 'Pokharia Muncipality': 'location_palika_582', 'Shibalaya  Rural Municipality': 'location_palika_583', 'Jagarnathpur Rural Muncipality': 'location_palika_584', 'Dhobini Rural Muncipality': 'location_palika_585', 'Dulpo duddha  Rural Municipality': 'location_palika_586', 'Chipaharmai Rural Muncipality': 'location_palika_587', 'She phoksundo  Rural Municipality': 'location_palika_588', 'Jagdulla Rural Municipality': 'location_palika_589', 'Pakaha Mainpur Rural Muncipality': 'location_palika_590', 'Mudkecula  Rural Municipality': 'location_palika_591', 'Bindbasini Rural Muncipality': 'location_palika_592', 'Kaeke  Rural Municipality': 'location_palika_593', 'Charka tanson  Rural Municipality': 'location_palika_594', 'Sakhuwa Parsauni Rural Muncipality': 'location_palika_595', 'Kankasundari Rural Municipality': 'location_palika_596', 'Sreja  Rural Municipality': 'location_palika_597', 'Paterwa sugauli Rural Muncipality': 'location_palika_598', 'Hima  Rural Municipality': 'location_palika_599', 'Tila  Rural Municipality': 'location_palika_600', 'Guthicaur  Rural Municipality': 'location_palika_601', 'Tatopani  Rural Municipality': 'location_palika_602', 'Patarasi  Rural Municipality': 'location_palika_603', 'Pachaljarana  Rural Municipality': 'location_palika_604', 'Satri tribeni  Rural Municipality': 'location_palika_605', 'Annapurna Rural Muncipality': 'location_palika_606', 'Narharinath  Rural Municipality': 'location_palika_607', 'Machapuche Rural Muncipality': 'location_palika_608', 'Mahabai  Rural Municipality': 'location_palika_609', 'Shuva Kalika Rural Municipality': 'location_palika_610', 'Parsagadhi Muncipality': 'location_palika_611', 'Jirabhawani Rural Muncipality': 'location_palika_612', 'Kuse  Rural Municipality': 'location_palika_613', 'Ghorakha Municipality': 'location_palika_614', 'Bandhipur Rural Municipality': 'location_palika_615', 'Madi Rural Muncipality': 'location_palika_616', 'Palata  Rural Municipality': 'location_palika_617', 'Rupa Rural Muncipality': 'location_palika_618', 'Chame Rural Muncipality': 'location_palika_619', 'Jaljala Rular Municipality': 'location_palika_620', 'Paiyu Rular Municipality': 'location_palika_621', 'Mahashila Rular Municipality': 'location_palika_622', 'Modi Rular Municipality': 'location_palika_623', 'Bihadi Rular Municipality': 'location_palika_624', 'Mugumakamarog  Rural Municipality': 'location_palika_625', 'Soru  Rural Municipality': 'location_palika_626', 'Khatyad  Rural Municipality': 'location_palika_627', 'Simkot  Rural Municipality': 'location_palika_628', 'Galkota Municipality': 'location_palika_629', 'Gharpaghang Rural Municipaltiy': 'location_palika_630', 'Namkha  Rural Municipality': 'location_palika_631', 'Thasang Rural Muncipalicity': 'location_palika_632', 'Khapunatha  Rural Municipality': 'location_palika_633', 'Lemthang Rural Muncipality': 'location_palika_634', 'Sarkegad  Rural Municipality': 'location_palika_635', 'Aadanculi  Rural Municipality': 'location_palika_636', 'Tajakot  Rural Municipality': 'location_palika_637', 'Bagchaur Muncipality': 'location_palika_638', 'Kalimati Rural Muncipality': 'location_palika_639', 'Tribeni Rural Muncipality': 'location_palika_640', 'Kapurkot  Rural Municipality': 'location_palika_641', 'Chatredhari  Rural Municipality': 'location_palika_642', 'Narpa Bhumi Rural Muncipality': 'location_palika_643', 'Aajunchaupari Rural Municipality': 'location_palika_644', 'Varagung Muktichhetra Rural Municipality': 'location_palika_645', 'Kumakh Rural Municipality': 'location_palika_646', 'Siddha Kumakh Rural Municipality': 'location_palika_647', 'Aadikhola Rural Municipality': 'location_palika_648', 'Biruba Rural Municipality': 'location_palika_649', 'Marinasa Rural Municipality': 'location_palika_650', 'Beni Municipality': 'location_palika_651', 'Annapurna Rural Municipality': 'location_palika_652', 'Dhaulagiri Rural Municipality': 'location_palika_653', 'Mangala Rural Municipality': 'location_palika_654', 'Malika Rural Municipality': 'location_palika_655', 'Raghu Rural Municipality': 'location_palika_656', 'wareng Rural Municipality': 'location_palika_657', 'Kathekhola Rural Municipality': 'location_palika_658', 'Tamankhola Rural Municipality': 'location_palika_659', 'Tarakhola Rural Municipality': 'location_palika_660', 'Nishikhola Rural Municipality': 'location_palika_661', 'Badigad Rural Municipality': 'location_palika_662', 'Darma  Rural Municipality': 'location_palika_663', 'Dhorpatan Municipality': 'location_palika_664', 'Sharadha municipality': 'location_palika_665', 'Bangad kupende Municipality': 'location_palika_666', 'Kabasoti Municipality': 'location_palika_667', 'Deumai Municipality': 'location_palika_668', 'Pachrauta Municipality': 'location_palika_669', 'Gokanaswor Municipality': 'location_palika_670', 'Sadhananda Municipality': 'location_palika_671', 'Suwarna Muncipality': 'location_palika_672', 'Simmarngadha Muncipality': 'location_palika_673', 'Shuklaphat Municipality': 'location_palika_674', 'Bhimeshwar  Municipaltiy': 'location_palika_675', 'rajadevi municipality': 'location_palika_676', 'Barahakshetra Municipaltiy': 'location_palika_677', 'Rajgadh RURAL MUNICIPALITY': 'location_palika_678', 'Nason Rural Muncipality': 'location_palika_679', 'Manang Ngisyang Rural Muncipality': 'location_palika_680', 'Binayi Tribeni Rural Municipality': 'location_palika_681', 'SUNIL SMRITI RURAL MUNICIPALITY': 'location_palika_682', 'nalgad Municipality': 'location_palika_683', 'Saipal Rural Municipality': 'location_palika_684', 'Pokhara Metropolitan City': 'location_palika_685', 'Temkemaiyum Rural Municipality': 'location_palika_686', 'Hatubagadhi Rural Municipality': 'location_palika_687', 'Rawabesi Rural Municipality': 'location_palika_688', 'Mapya Dudhakoshi Rural Municipality': 'location_palika_689', 'Manebhanjyan Rural Municipaltiy': 'location_palika_690', 'Bhadrapur Municipality': 'location_palika_691', 'Kanachanakabal Rural Municipality': 'location_palika_692', 'Biratnagar Metropolitan City': 'location_palika_693', 'Gramthan Rural Municipality': 'location_palika_694', 'Ithari Sub-Metropolitan City': 'location_palika_695', 'Duhabi Municipality': 'location_palika_696', 'Bhokraha Narsingh Rural Municipality': 'location_palika_697', 'Harinagar Rural Municipality': 'location_palika_698', 'Bodebarsain Municipality': 'location_palika_699', 'Baudikali Rural Municipality': 'location_palika_700', 'palhinnadan Rural Municipality': 'location_palika_701', 'Saptakoshi Municipality': 'location_palika_702', 'Sakhunankarakatti Rural Municipality': 'location_palika_703', 'Gaurisankar Rural Municipality': 'location_palika_704', 'Tamakoshi Rural Municipality': 'location_palika_705', 'Sailung Rural Municipality': 'location_palika_706', 'Melunga Rural Municipality': 'location_palika_707', 'Baiteswar Rural Municipality': 'location_palika_708', 'Bigu Rural Municipality': 'location_palika_709', 'Kamalamai Municipality': 'location_palika_710', 'Sunkoshi Rural Municipaltiy': 'location_palika_711', 'Kispanga Rural Municipality': 'location_palika_712', 'Gangajamuna Rural Municipality': 'location_palika_713', 'Jawalamukhi Rural Municipality': 'location_palika_714', 'Thakre Rural Municipality': 'location_palika_715', 'Netrawati Dabjong Rural Municipality': 'location_palika_716', 'Benighat Roranga Rural Municipality': 'location_palika_717', 'Ruvi Valley Rural Municipality': 'location_palika_718', 'Siddhalek Rural Municipality': 'location_palika_719', 'Tripurasundhari Rural Municipality': 'location_palika_720', 'Aajirkot Rural Municipality': 'location_palika_721', 'Arughat Rural Municipality': 'location_palika_722', 'Chumanuwrimun Rural Municipality': 'location_palika_723', 'Bhimad Municipality': 'location_palika_724', 'Payasa Municipality': 'location_palika_725', 'Suklagandaki Municipality': 'location_palika_726', 'Shisenga Rural Municipality': 'location_palika_727', 'Debaghat Rural Municipality': 'location_palika_728', 'Maygde Rural Municipality': 'location_palika_729', 'Lo Ghekar Damodarkunda Rural Municipality': 'location_palika_730', 'Kaligandaki Rural Municipality': 'location_palika_731', 'fedikhola Rural Municipality': 'location_palika_732', 'Yashodhara Rural Municipality': 'location_palika_733', 'Bijayanagar Rural Municipality': 'location_palika_735', 'Rampur Municipality': 'location_palika_736', 'Balan Bihul Rural MUNICIPALITY': 'location_palika_737', 'Musikot Municipality': 'location_palika_738', 'Susta Ruralmunicipality': 'location_palika_739', 'Kirtipur Municipality': 'location_palika_740', 'Chiresanata Rural Municipaltiy': 'location_palika_741', 'Mithila Bihari  Municipality': 'location_palika_742', 'Shahidnagar Municipality': 'location_palika_743', 'Pansakanya Rural Municipality': 'location_palika_745', 'Dhanauji Rural Municipality': 'location_palika_746', 'Garuda Muncipality': 'location_palika_747', 'Katahariya Muncipality': 'location_palika_748', 'Yamunamai Rural Municipality': 'location_palika_749', 'Bisrampur Rural Municipality': 'location_palika_750', 'Bahudramai  Muncipality': 'location_palika_751', 'thori Rural Municipality': 'location_palika_752', 'Myagang Rural Municipality': 'location_palika_753', 'Kalikamai Rural Mumcipality': 'location_palika_754'}

# %%
dictionary={}
# print(district_dictionary.keys())
for data in csv.iterrows():
#     print(data[1]['name'])
    if str(data[1]["name"]) in district_dictionary:
        dictionary[str(int(data[1]['id']))]=district_dictionary[data[1]["name"]]
print(dictionary)
# Out:
# {'2058': 'location_district_1', '2071': 'location_district_2', '2059': 'location_district_3', '2072': 'location_district_4', '2073': 'location_district_5', '2074': 'location_district_6', '2008': 'location_district_7', '2009': 'location_district_8', '2010': 'location_district_9', '2011': 'location_district_10', '2012': 'location_district_11', '2013': 'location_district_12', '2014': 'location_district_13', '2015': 'location_district_14', '2016': 'location_district_15', '2017': 'location_district_16', '2018': 'location_district_17', '2019': 'location_district_18', '2020': 'location_district_19', '2021': 'location_district_20', '2022': 'location_district_21', '2023': 'location_district_22', '2024': 'location_district_23', '2025': 'location_district_24', '2026': 'location_district_25', '2027': 'location_district_26', '2028': 'location_district_27', '2029': 'location_district_28', '2030': 'location_district_29', '2031': 'location_district_30', '2032': 'location_district_31', '2033': 'locat
# ...

# %% [markdown]
# <odoo>
#     <data noupdate='1'>
#
# 	<record id="location_province_1" model="location.province">
# 		<field name="name">Province No. 1</field>
#
# </record>
# 	<record id="location_province_2" model="location.province">
# 		<field name="name">Province No. 2</field>
#
# </record>
# 	<record id="location_province_3" model="location.province">
# 		<field name="name">Bagmati</field>
#
# </record>
# 	<record id="location_province_4" model="location.province">
# 		<field name="name">Gandaki</field>
#
# </record>
# 	<record id="location_province_5" model="location.province">
# 		<field name="name">Lumbini</field>
#
# </record>
# 	<record id="location_province_6" model="location.province">
# 		<field name="name">Karnali</field>
#
# </record>
# 	<record id="location_province_7" model="location.province">
# 		<field name="name">Sudurpashchim</field>
#
# </record>
# </data>
# </odoo>

# %%
model='location.palika'
model_underscore="location_palika_"
id = 1

res = "<odoo>\n\t<data noupdate='0'>\n"
dict = {}
for data in csv.iterrows():
    if str(data[1]["name"]) in district_dictionary:
        continue
    temp = "\t<record id='" + str(model_underscore) + str(id) +  "' model='" + model + "'>\n"
    temp += "\t\t<field name='district_name' ref='farmer." + dictionary[str(int(data[1]['parent']))] + "'></field>\n"
    temp += "\t\t<field name='palika_name'>" + str(data[1]['name']) + "</field>\n"
    temp += "\t\t<field name='palika_name_np'>" + str(data[1]['name_np']) + "</field>\n"
    temp += "\t\t<field name='reference_id'>" + str(data[1]['id']) + "</field>\n"
    temp += "\t\t<field name='reference_code'>" + str(data[1]['code']) + "</field>\n"
    temp += "\t</record>\n"
    res += str(temp)
    dict[str(data[1]['name'])] = str(model_underscore) + str(id)
    id += 1
res += "\t</data>\n</odoo>\n"
print(res)
print(dict)
# Out:
# <odoo>
# 	<data noupdate='0'>
# 	<record id='location_palika_1' model='location.palika'>
# 		<field name='district_name' ref='farmer.location_district_25'></field>
# 		<field name='palika_name'>Basbariya Rural Municipality</field>
# 		<field name='palika_name_np'>बसबरिया गाउँपालिका</field>
# 		<field name='reference_id'>3075</field>
# 		<field name='reference_code'>2481</field>
# 	</record>
# 	<record id='location_palika_2' model='location.palika'>
# 		<field name='district_name' ref='farmer.location_district_25'></field>
# 		<field name='palika_name'>Kodena Rural Municipality</field>
# 		<field name='palika_name_np'>कोडैना गाउँपालिका</field>
# 		<field name='reference_id'>3076</field>
# 		<field name='reference_code'>2482</field>
# 	</record>
# 	<record id='location_palika_3' model='location.palika'>
# 		<field name='district_name' ref='farmer.location_district_25'></field>
# 		<field name='palika_name'>Parsa Rural Municipality</field>
# ...

# %%
def return_id(name):
    if name=='Province No. 1':
        return 1
    if name=='Province No. 2':
        return 2
    if name=='Bagmati':
        return 3
    if name=='Gandaki':
        return 4
    if name=='Lumbini':
        return 5
    if name=='Karnali':
        return 6
    if name=='Sudurpashchim':
        return 7

# %%
# list(csv.groupby('Province'))

# %%
temp="""<odoo>
    <data noupdate='1'>\n"""

# %%
int_id_district=1

# %%
id_int=1

# %%
# for item in list(csv.groupby('Province')):
#     for row,district in item[1].iterrows():
# #         print(district['District'])
        
#         temp+=f"""\n\t<record id="{model_underscore}_{int_id_district}" model="{model}">\n"""
#         temp+=f'\t\t<field name="district_name">'+district['District']+'</field>\n'
#         temp+=f'\t\t<field name="province_name">'+str(return_id(item[0]))+'</field>\n'
#         temp+="""\n</record>"""
#         int_id_district+=1
        
#     id_int+=1

# %%
temp+="""
</data>
</odoo>
"""

# %%
temp
# Out:
# '<odoo>\n    <data noupdate=\'1\'>\n\n\t<record id="location_district_1" model="location.district">\n\t\t<field name="district_name">Sindhuli</field>\n\t\t<field name="province_name">3</field>\n\n</record>\n\t<record id="location_district_2" model="location.district">\n\t\t<field name="district_name">Ramechhap</field>\n\t\t<field name="province_name">3</field>\n\n</record>\n\t<record id="location_district_3" model="location.district">\n\t\t<field name="district_name">Dolakha</field>\n\t\t<field name="province_name">3</field>\n\n</record>\n\t<record id="location_district_4" model="location.district">\n\t\t<field name="district_name">Bhaktapur</field>\n\t\t<field name="province_name">3</field>\n\n</record>\n\t<record id="location_district_5" model="location.district">\n\t\t<field name="district_name">Dhading</field>\n\t\t<field name="province_name">3</field>\n\n</record>\n\t<record id="location_district_6" model="location.district">\n\t\t<field name="district_name">Kathmandu</field>\n\
# ...

# %%
def return_value(value):
    if value == 'nan':
        return ""
    return value

# %%
columns=csv.columns

# %%
for ind, row in csv.iterrows():
    temp+=f"""\n\t<record id="{model_underscore}_{ind}" model="{model}">\n"""
    for column in columns:
        temp+=f'\t\t<field name="{column}">'+str(return_value(row[column]))+'</field>\n'
    temp+="""\n</record>"""

# %%
temp+="""
</data>
</odoo>
"""

# %%
with open("district_data.xml",'w') as out:
    out.write(temp)
